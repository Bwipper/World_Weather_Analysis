# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import random
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates =  list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
city_list = [] 

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
     if city not in city_list:
       city_list.append(city)

# Print the city count to confirm sufficient count
len(city_list)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(city_list):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_description = city_weather["weather"][0]["description"]   
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | esperance
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | ostrovnoy
# Processing Record 7 of Set 1 | yeppoon
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | rio gallegos
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 1 | nawalapitiya
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | bud
# Processing Record 17 of Set 1 | necochea
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | poli
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | brae
# Processing Record 24 of Set 1 | yar-sale
# Processing Record 25 of Set 1 | mae sai
# Processing Record 26 of Set 1 | villa constitucion
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | tupik
# Processing Record 29 of Set 1 | itoman
# Processing Record 30 of Set 1 | mana
# Processing Record 31 of Set 1 | terme
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | tiarei
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | komsomolskiy
# Processing Record 39 of Set 1 | vao
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | yichun
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | atambua
# Processing Record 48 of Set 1 | katobu
# Processing Record 49 of Set 1 | werkendam
# Processing Record 50 of Set 1 | rawson
# Processing Record 1 of Set 2 | deputatskiy
# Processing Record 2 of Set 2 | svetlaya
# Processing Record 3 of Set 2 | vostok
# Processing Record 4 of Set 2 | khandyga
# Processing Record 5 of Set 2 | hofn
# Processing Record 6 of Set 2 | cozumel
# Processing Record 7 of Set 2 | nacala
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | ahipara
# Processing Record 10 of Set 2 | batangafo
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | barsovo
# Processing Record 15 of Set 2 | springbok
# Processing Record 16 of Set 2 | meadow lake
# Processing Record 17 of Set 2 | san policarpo
# Processing Record 18 of Set 2 | lashio
# Processing Record 19 of Set 2 | the valley
# Processing Record 20 of Set 2 | merauke
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | whitewater
# Processing Record 24 of Set 2 | cangzhou
# Processing Record 25 of Set 2 | gao
# Processing Record 26 of Set 2 | kuytun
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | kikwit
# Processing Record 32 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | butterworth
# Processing Record 35 of Set 2 | vestmannaeyjar
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | yulara
# Processing Record 38 of Set 2 | tsiroanomandidy
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | beringovskiy
# Processing Record 41 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 2 | tura
# Processing Record 43 of Set 2 | banjar
# Processing Record 44 of Set 2 | husavik
# Processing Record 45 of Set 2 | port hedland
# Processing Record 46 of Set 2 | tautira
# Processing Record 47 of Set 2 | christchurch
# Processing Record 48 of Set 2 | bar harbor
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | agirish
# Processing Record 1 of Set 3 | denpasar
# Processing Record 2 of Set 3 | varna
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | verkh-chebula
# Processing Record 6 of Set 3 | saint-philippe
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | klaksvik
# Processing Record 12 of Set 3 | busselton
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | solnechnyy
# Processing Record 15 of Set 3 | kandrian
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | creel
# Processing Record 18 of Set 3 | makakilo city
# Processing Record 19 of Set 3 | acolla
# Processing Record 20 of Set 3 | wanning
# Processing Record 21 of Set 3 | manjacaze
# Processing Record 22 of Set 3 | kavaratti
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | diego de almagro
# Processing Record 25 of Set 3 | bushehr
# Processing Record 26 of Set 3 | zhangjiakou
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | yeniseysk
# Processing Record 29 of Set 3 | port-gentil
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | perbaungan
# Processing Record 32 of Set 3 | chiang khong
# Processing Record 33 of Set 3 | korla
# Processing Record 34 of Set 3 | constitucion
# Processing Record 35 of Set 3 | esil
# Processing Record 36 of Set 3 | ilulissat
# Processing Record 37 of Set 3 | inhambane
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | namibe
# Processing Record 40 of Set 3 | sao jose da coroa grande
# Processing Record 41 of Set 3 | korem
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | bolonchen
# City not found. Skipping...
# Processing Record 44 of Set 3 | marawi
# Processing Record 45 of Set 3 | senanga
# Processing Record 46 of Set 3 | campbell river
# Processing Record 47 of Set 3 | pevek
# Processing Record 48 of Set 3 | tabanan
# Processing Record 49 of Set 3 | pishin
# Processing Record 50 of Set 3 | hilo
# Processing Record 1 of Set 4 | diamantino
# Processing Record 2 of Set 4 | galeana
# Processing Record 3 of Set 4 | kysyl-syr
# Processing Record 4 of Set 4 | banda aceh
# Processing Record 5 of Set 4 | esik
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | cimislia
# Processing Record 8 of Set 4 | sciacca
# Processing Record 9 of Set 4 | fort nelson
# Processing Record 10 of Set 4 | puerto madryn
# Processing Record 11 of Set 4 | kalmunai
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | maumere
# Processing Record 14 of Set 4 | caravelas
# Processing Record 15 of Set 4 | abu samrah
# Processing Record 16 of Set 4 | sungairaya
# Processing Record 17 of Set 4 | muros
# Processing Record 18 of Set 4 | amahai
# Processing Record 19 of Set 4 | gat
# Processing Record 20 of Set 4 | jaguey grande
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | abaete
# Processing Record 23 of Set 4 | orange cove
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | lagoa
# Processing Record 27 of Set 4 | mombaca
# Processing Record 28 of Set 4 | yenagoa
# Processing Record 29 of Set 4 | beira
# Processing Record 30 of Set 4 | corner brook
# Processing Record 31 of Set 4 | chacabuco
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 4 | provideniya
# Processing Record 36 of Set 4 | tuatapere
# Processing Record 37 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 38 of Set 4 | orikhove
# Processing Record 39 of Set 4 | hirara
# Processing Record 40 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 4 | lufilufi
# Processing Record 42 of Set 4 | yinchuan
# Processing Record 43 of Set 4 | katha
# City not found. Skipping...
# Processing Record 44 of Set 4 | codrington
# Processing Record 45 of Set 4 | pundaguitan
# Processing Record 46 of Set 4 | maua
# Processing Record 47 of Set 4 | tecoanapa
# Processing Record 48 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4 | coquimbo
# Processing Record 1 of Set 5 | iqaluit
# Processing Record 2 of Set 5 | ust-kuyga
# Processing Record 3 of Set 5 | port alfred
# Processing Record 4 of Set 5 | maniitsoq
# Processing Record 5 of Set 5 | dikson
# Processing Record 6 of Set 5 | talesh
# City not found. Skipping...
# Processing Record 7 of Set 5 | goderich
# Processing Record 8 of Set 5 | riyadh
# Processing Record 9 of Set 5 | placido de castro
# Processing Record 10 of Set 5 | hovd
# Processing Record 11 of Set 5 | kaitangata
# Processing Record 12 of Set 5 | cockburn town
# Processing Record 13 of Set 5 | vysokogornyy
# Processing Record 14 of Set 5 | flin flon
# Processing Record 15 of Set 5 | quesnel
# Processing Record 16 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 5 | sakaiminato
# Processing Record 18 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 5 | omsukchan
# Processing Record 20 of Set 5 | killybegs
# Processing Record 21 of Set 5 | mamou
# Processing Record 22 of Set 5 | lavrentiya
# Processing Record 23 of Set 5 | labuhan
# Processing Record 24 of Set 5 | blama
# Processing Record 25 of Set 5 | sinnamary
# Processing Record 26 of Set 5 | hami
# Processing Record 27 of Set 5 | margate
# Processing Record 28 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 5 | shimoda
# Processing Record 30 of Set 5 | mahanoro
# Processing Record 31 of Set 5 | jian
# Processing Record 32 of Set 5 | okmulgee
# Processing Record 33 of Set 5 | trairi
# Processing Record 34 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 35 of Set 5 | kuminskiy
# Processing Record 36 of Set 5 | porto de moz
# Processing Record 37 of Set 5 | sarkand
# Processing Record 38 of Set 5 | mitsamiouli
# Processing Record 39 of Set 5 | port elizabeth
# Processing Record 40 of Set 5 | goure
# Processing Record 41 of Set 5 | morondava
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | kudahuvadhoo
# Processing Record 44 of Set 5 | cidreira
# Processing Record 45 of Set 5 | victoria
# Processing Record 46 of Set 5 | los llanos de aridane
# Processing Record 47 of Set 5 | leningradskiy
# Processing Record 48 of Set 5 | shelburne
# Processing Record 49 of Set 5 | buala
# Processing Record 50 of Set 5 | college
# Processing Record 1 of Set 6 | arlit
# Processing Record 2 of Set 6 | nemuro
# Processing Record 3 of Set 6 | bilma
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | nikolskoye
# Processing Record 6 of Set 6 | attur
# Processing Record 7 of Set 6 | salinas
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | pontes e lacerda
# Processing Record 10 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 6 | hasaki
# Processing Record 12 of Set 6 | cherepovets
# Processing Record 13 of Set 6 | arman
# Processing Record 14 of Set 6 | tiksi
# Processing Record 15 of Set 6 | uyemskiy
# Processing Record 16 of Set 6 | omboue
# Processing Record 17 of Set 6 | ovsyanka
# Processing Record 18 of Set 6 | bambous virieux
# Processing Record 19 of Set 6 | kutum
# Processing Record 20 of Set 6 | geraldton
# Processing Record 21 of Set 6 | xuanzhou
# Processing Record 22 of Set 6 | kerman
# Processing Record 23 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 6 | katsuura
# Processing Record 25 of Set 6 | eirunepe
# Processing Record 26 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 6 | acapulco
# Processing Record 28 of Set 6 | suluq
# Processing Record 29 of Set 6 | waddan
# Processing Record 30 of Set 6 | sisimiut
# Processing Record 31 of Set 6 | sao felix do xingu
# Processing Record 32 of Set 6 | grand baie
# Processing Record 33 of Set 6 | lagos
# Processing Record 34 of Set 6 | os
# City not found. Skipping...
# Processing Record 35 of Set 6 | kresek
# Processing Record 36 of Set 6 | kahului
# Processing Record 37 of Set 6 | saint george
# Processing Record 38 of Set 6 | lorengau
# Processing Record 39 of Set 6 | ayan
# Processing Record 40 of Set 6 | wynyard
# Processing Record 41 of Set 6 | beyneu
# Processing Record 42 of Set 6 | manaure
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | la ronge
# Processing Record 45 of Set 6 | yafran
# Processing Record 46 of Set 6 | asau
# Processing Record 47 of Set 6 | nurota
# Processing Record 48 of Set 6 | nuuk
# Processing Record 49 of Set 6 | airai
# Processing Record 50 of Set 6 | cayenne
# Processing Record 1 of Set 7 | maceio
# Processing Record 2 of Set 7 | guiratinga
# Processing Record 3 of Set 7 | porbandar
# Processing Record 4 of Set 7 | boyolangu
# Processing Record 5 of Set 7 | mehran
# Processing Record 6 of Set 7 | el dorado
# Processing Record 7 of Set 7 | taoudenni
# Processing Record 8 of Set 7 | sorong
# Processing Record 9 of Set 7 | bayan
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | talnakh
# Processing Record 12 of Set 7 | ndende
# Processing Record 13 of Set 7 | grand gaube
# Processing Record 14 of Set 7 | kargasok
# Processing Record 15 of Set 7 | llangefni
# Processing Record 16 of Set 7 | naples
# Processing Record 17 of Set 7 | andenes
# Processing Record 18 of Set 7 | shingu
# Processing Record 19 of Set 7 | camacha
# Processing Record 20 of Set 7 | karratha
# Processing Record 21 of Set 7 | bandar
# Processing Record 22 of Set 7 | edd
# Processing Record 23 of Set 7 | bikaner
# Processing Record 24 of Set 7 | ancud
# Processing Record 25 of Set 7 | melfi
# Processing Record 26 of Set 7 | srednekolymsk
# Processing Record 27 of Set 7 | chapais
# Processing Record 28 of Set 7 | bubaque
# Processing Record 29 of Set 7 | port macquarie
# Processing Record 30 of Set 7 | marsabit
# Processing Record 31 of Set 7 | paka
# Processing Record 32 of Set 7 | olafsvik
# Processing Record 33 of Set 7 | samfya
# Processing Record 34 of Set 7 | nhulunbuy
# Processing Record 35 of Set 7 | evans
# Processing Record 36 of Set 7 | ambatofinandrahana
# Processing Record 37 of Set 7 | buin
# Processing Record 38 of Set 7 | flinders
# Processing Record 39 of Set 7 | pascagoula
# Processing Record 40 of Set 7 | nautla
# Processing Record 41 of Set 7 | mineral wells
# Processing Record 42 of Set 7 | narsaq
# Processing Record 43 of Set 7 | praia da vitoria
# Processing Record 44 of Set 7 | basoko
# Processing Record 45 of Set 7 | bandarbeyla
# Processing Record 46 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 7 | kavieng
# Processing Record 48 of Set 7 | alekseyevka
# Processing Record 49 of Set 7 | port-cartier
# Processing Record 50 of Set 7 | lusambo
# Processing Record 1 of Set 8 | roald
# Processing Record 2 of Set 8 | davydovka
# Processing Record 3 of Set 8 | pekin
# Processing Record 4 of Set 8 | inta
# Processing Record 5 of Set 8 | bengkulu
# Processing Record 6 of Set 8 | kailua
# Processing Record 7 of Set 8 | nanortalik
# Processing Record 8 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 8 | havoysund
# Processing Record 10 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 8 | saint anthony
# Processing Record 12 of Set 8 | pierre
# Processing Record 13 of Set 8 | high prairie
# Processing Record 14 of Set 8 | belmonte
# Processing Record 15 of Set 8 | boguchany
# Processing Record 16 of Set 8 | bilibino
# Processing Record 17 of Set 8 | saldanha
# Processing Record 18 of Set 8 | mahebourg
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | ust-maya
# Processing Record 21 of Set 8 | khiri mat
# Processing Record 22 of Set 8 | kulhudhuffushi
# Processing Record 23 of Set 8 | padang
# Processing Record 24 of Set 8 | baiquan
# Processing Record 25 of Set 8 | wanaka
# Processing Record 26 of Set 8 | remeti
# Processing Record 27 of Set 8 | hamilton
# Processing Record 28 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 8 | karaj
# Processing Record 30 of Set 8 | fort-shevchenko
# Processing Record 31 of Set 8 | miri
# Processing Record 32 of Set 8 | carnarvon
# Processing Record 33 of Set 8 | tiznit
# Processing Record 34 of Set 8 | igurusi
# Processing Record 35 of Set 8 | urengoy
# Processing Record 36 of Set 8 | kamenka
# Processing Record 37 of Set 8 | tadine
# Processing Record 38 of Set 8 | naze
# Processing Record 39 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 8 | sete
# Processing Record 41 of Set 8 | fare
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | abha
# Processing Record 44 of Set 8 | sibulan
# Processing Record 45 of Set 8 | pecos
# Processing Record 46 of Set 8 | polovinnoye
# Processing Record 47 of Set 8 | yamasaki
# Processing Record 48 of Set 8 | jalu
# Processing Record 49 of Set 8 | chillicothe
# Processing Record 50 of Set 8 | krapivinskiy
# Processing Record 1 of Set 9 | villazon
# Processing Record 2 of Set 9 | cherskiy
# Processing Record 3 of Set 9 | quelimane
# Processing Record 4 of Set 9 | emporia
# Processing Record 5 of Set 9 | guymon
# Processing Record 6 of Set 9 | carutapera
# Processing Record 7 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 8 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 9 | vitim
# Processing Record 10 of Set 9 | roebourne
# Processing Record 11 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 9 | yining
# Processing Record 13 of Set 9 | gizo
# Processing Record 14 of Set 9 | north bend
# Processing Record 15 of Set 9 | marovoay
# Processing Record 16 of Set 9 | hay river
# Processing Record 17 of Set 9 | tapes
# Processing Record 18 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 9 | kunming
# Processing Record 20 of Set 9 | byron bay
# Processing Record 21 of Set 9 | aligarh
# Processing Record 22 of Set 9 | sotik
# Processing Record 23 of Set 9 | ardino
# Processing Record 24 of Set 9 | mossendjo
# Processing Record 25 of Set 9 | san mariano
# Processing Record 26 of Set 9 | sawtell
# Processing Record 27 of Set 9 | dingle
# Processing Record 28 of Set 9 | presidente medici
# Processing Record 29 of Set 9 | half moon bay
# Processing Record 30 of Set 9 | taber
# Processing Record 31 of Set 9 | andra
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | simbahan
# Processing Record 34 of Set 9 | grindavik
# Processing Record 35 of Set 9 | bereda
# Processing Record 36 of Set 9 | taltal
# Processing Record 37 of Set 9 | san quintin
# Processing Record 38 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 9 | formosa do rio preto
# Processing Record 40 of Set 9 | cabedelo
# Processing Record 41 of Set 9 | guanica
# Processing Record 42 of Set 9 | miguel auza
# Processing Record 43 of Set 9 | nouadhibou
# Processing Record 44 of Set 9 | sajanan
# Processing Record 45 of Set 9 | kasongo-lunda
# Processing Record 46 of Set 9 | salamanca
# Processing Record 47 of Set 9 | zhigansk
# Processing Record 48 of Set 9 | sangar
# Processing Record 49 of Set 9 | berlevag
# Processing Record 50 of Set 9 | salair
# Processing Record 1 of Set 10 | hobyo
# Processing Record 2 of Set 10 | horni benesov
# Processing Record 3 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 10 | pangnirtung
# Processing Record 5 of Set 10 | boa viagem
# Processing Record 6 of Set 10 | faya
# Processing Record 7 of Set 10 | almaznyy
# Processing Record 8 of Set 10 | xichang
# Processing Record 9 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 10 | independence
# Processing Record 11 of Set 10 | kirakira
# Processing Record 12 of Set 10 | itarema
# Processing Record 13 of Set 10 | ballina
# Processing Record 14 of Set 10 | sayyan
# Processing Record 15 of Set 10 | darovskoy
# Processing Record 16 of Set 10 | ranau
# Processing Record 17 of Set 10 | tarumovka
# Processing Record 18 of Set 10 | uusikaupunki
# Processing Record 19 of Set 10 | ekhabi
# Processing Record 20 of Set 10 | marystown
# Processing Record 21 of Set 10 | jiangyou
# Processing Record 22 of Set 10 | nagod
# Processing Record 23 of Set 10 | furtwangen
# Processing Record 24 of Set 10 | pitimbu
# Processing Record 25 of Set 10 | wagga wagga
# Processing Record 26 of Set 10 | ekimchan
# Processing Record 27 of Set 10 | aklavik
# Processing Record 28 of Set 10 | along
# Processing Record 29 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 30 of Set 10 | andros town
# Processing Record 31 of Set 10 | seoul
# Processing Record 32 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 10 | nome
# Processing Record 34 of Set 10 | ambon
# Processing Record 35 of Set 10 | portland
# Processing Record 36 of Set 10 | henzada
# City not found. Skipping...
# Processing Record 37 of Set 10 | jizan
# Processing Record 38 of Set 10 | carmen del parana
# Processing Record 39 of Set 10 | nara
# Processing Record 40 of Set 10 | chumikan
# Processing Record 41 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 10 | kyra
# Processing Record 43 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 10 | te anau
# Processing Record 45 of Set 10 | araouane
# Processing Record 46 of Set 10 | quatre cocos
# Processing Record 47 of Set 10 | balvi
# Processing Record 48 of Set 10 | santa cruz
# Processing Record 49 of Set 10 | houma
# Processing Record 50 of Set 10 | verkhoyansk
# Processing Record 1 of Set 11 | bucerias
# Processing Record 2 of Set 11 | channel-port aux basques
# Processing Record 3 of Set 11 | akranes
# Processing Record 4 of Set 11 | mecca
# Processing Record 5 of Set 11 | egvekinot
# Processing Record 6 of Set 11 | kijang
# Processing Record 7 of Set 11 | hede
# Processing Record 8 of Set 11 | hondo
# Processing Record 9 of Set 11 | mayumba
# Processing Record 10 of Set 11 | puerto carreno
# Processing Record 11 of Set 11 | sioux city
# Processing Record 12 of Set 11 | aizpute
# Processing Record 13 of Set 11 | oudtshoorn
# Processing Record 14 of Set 11 | otjimbingwe
# Processing Record 15 of Set 11 | atasu
# Processing Record 16 of Set 11 | narrabri
# Processing Record 17 of Set 11 | ust-ilimsk
# Processing Record 18 of Set 11 | lujan
# Processing Record 19 of Set 11 | chabahar
# Processing Record 20 of Set 11 | seminole
# Processing Record 21 of Set 11 | zarand
# Processing Record 22 of Set 11 | gopalpur
# Processing Record 23 of Set 11 | oranjestad
# Processing Record 24 of Set 11 | tral
# Processing Record 25 of Set 11 | conceicao da barra
# Processing Record 26 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | sioux lookout
# Processing Record 29 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 30 of Set 11 | dunedin
# Processing Record 31 of Set 11 | sao filipe
# Processing Record 32 of Set 11 | road town
# Processing Record 33 of Set 11 | nizhnevartovsk
# Processing Record 34 of Set 11 | lazarev
# Processing Record 35 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 11 | iberia
# Processing Record 37 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 11 | coahuayana
# Processing Record 39 of Set 11 | ixtapa
# Processing Record 40 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 11 | adrar
# Processing Record 42 of Set 11 | mahina
# Processing Record 43 of Set 11 | mackay
# Processing Record 44 of Set 11 | somerset west
# Processing Record 45 of Set 11 | sestri levante
# Processing Record 46 of Set 11 | mandalgovi
# Processing Record 47 of Set 11 | cap malheureux
# Processing Record 48 of Set 11 | saint-joseph
# Processing Record 49 of Set 11 | contamana
# Processing Record 50 of Set 11 | yerbogachen
# Processing Record 1 of Set 12 | havelock
# Processing Record 2 of Set 12 | henties bay
# Processing Record 3 of Set 12 | marzuq
# Processing Record 4 of Set 12 | hovelhof
# Processing Record 5 of Set 12 | gamba
# Processing Record 6 of Set 12 | udalguri
# Processing Record 7 of Set 12 | salekhard
# Processing Record 8 of Set 12 | umea
# Processing Record 9 of Set 12 | port lincoln
# Processing Record 10 of Set 12 | tonj
# Processing Record 11 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 12 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 13 of Set 12 | azovo
# Processing Record 14 of Set 12 | tahoua
# Processing Record 15 of Set 12 | doha
# Processing Record 16 of Set 12 | erzin
# Processing Record 17 of Set 12 | kieta
# Processing Record 18 of Set 12 | nizwa
# Processing Record 19 of Set 12 | ponta delgada
# Processing Record 20 of Set 12 | yei
# Processing Record 21 of Set 12 | freeport
# Processing Record 22 of Set 12 | floro
# Processing Record 23 of Set 12 | smyrna
# Processing Record 24 of Set 12 | hulan
# Processing Record 25 of Set 12 | kalianget
# Processing Record 26 of Set 12 | bilgoraj
# Processing Record 27 of Set 12 | suntar
# Processing Record 28 of Set 12 | vilhena
# Processing Record 29 of Set 12 | samarai
# Processing Record 30 of Set 12 | batticaloa
# Processing Record 31 of Set 12 | ndjole
# Processing Record 32 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 12 | khromtau
# Processing Record 34 of Set 12 | champerico
# Processing Record 35 of Set 12 | muravlenko
# Processing Record 36 of Set 12 | zaragoza
# Processing Record 37 of Set 12 | kaohsiung
# Processing Record 38 of Set 12 | kiunga
# Processing Record 39 of Set 12 | boa vista
# Processing Record 40 of Set 12 | clyde river
# Processing Record 41 of Set 12 | eureka
# Processing Record 42 of Set 12 | chagoda
# Processing Record 43 of Set 12 | russell
# Processing Record 44 of Set 12 | dryden
# Processing Record 45 of Set 12 | cairns
# Processing Record 46 of Set 12 | stadtbredimus
# Processing Record 47 of Set 12 | alta floresta
# Processing Record 48 of Set 12 | beni mazar
# Processing Record 49 of Set 12 | barcelos
# Processing Record 50 of Set 12 | mehamn
# Processing Record 1 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 13 | mersing
# Processing Record 3 of Set 13 | krasnokamensk
# Processing Record 4 of Set 13 | teahupoo
# Processing Record 5 of Set 13 | lincoln
# Processing Record 6 of Set 13 | gotsu
# Processing Record 7 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 8 of Set 13 | varadero
# Processing Record 9 of Set 13 | batemans bay
# Processing Record 10 of Set 13 | temba
# Processing Record 11 of Set 13 | harper
# Processing Record 12 of Set 13 | phalodi
# Processing Record 13 of Set 13 | qianguo
# Processing Record 14 of Set 13 | olinda
# Processing Record 15 of Set 13 | natal
# Processing Record 16 of Set 13 | teyateyaneng
# Processing Record 17 of Set 13 | coruripe
# Processing Record 18 of Set 13 | hirado
# Processing Record 19 of Set 13 | sovetskaya gavan
# Processing Record 20 of Set 13 | rumoi
# Processing Record 21 of Set 13 | lisakovsk
# Processing Record 22 of Set 13 | egersund
# Processing Record 23 of Set 13 | panaba
# Processing Record 24 of Set 13 | oranjemund
# Processing Record 25 of Set 13 | baruun-urt
# Processing Record 26 of Set 13 | ferme-neuve
# Processing Record 27 of Set 13 | ballinasloe
# Processing Record 28 of Set 13 | tommot
# Processing Record 29 of Set 13 | alegrete
# Processing Record 30 of Set 13 | jasper
# Processing Record 31 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 13 | calabozo
# Processing Record 33 of Set 13 | sao borja
# Processing Record 34 of Set 13 | oksfjord
# Processing Record 35 of Set 13 | akom
# Processing Record 36 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 37 of Set 13 | veraval
# Processing Record 38 of Set 13 | townsville
# Processing Record 39 of Set 13 | westport
# Processing Record 40 of Set 13 | opuwo
# Processing Record 41 of Set 13 | pa sang
# Processing Record 42 of Set 13 | maragogi
# Processing Record 43 of Set 13 | bairiki
# Processing Record 44 of Set 13 | millville
# Processing Record 45 of Set 13 | praya
# Processing Record 46 of Set 13 | nampa
# Processing Record 47 of Set 13 | isla vista
# Processing Record 48 of Set 13 | biak
# Processing Record 49 of Set 13 | walvis bay
# Processing Record 50 of Set 13 | panama city
# Processing Record 1 of Set 14 | dilla
# Processing Record 2 of Set 14 | kindu
# Processing Record 3 of Set 14 | shenjiamen
# Processing Record 4 of Set 14 | bahir dar
# Processing Record 5 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 6 of Set 14 | orotukan
# Processing Record 7 of Set 14 | raudeberg
# Processing Record 8 of Set 14 | toropets
# Processing Record 9 of Set 14 | matamba
# Processing Record 10 of Set 14 | oistins
# Processing Record 11 of Set 14 | bonavista
# Processing Record 12 of Set 14 | zeya
# Processing Record 13 of Set 14 | tir pol
# City not found. Skipping...
# Processing Record 14 of Set 14 | lyskovo
# Processing Record 15 of Set 14 | baie-comeau
# Processing Record 16 of Set 14 | nabire
# Processing Record 17 of Set 14 | chengde
# Processing Record 18 of Set 14 | camocim
# Processing Record 19 of Set 14 | waingapu
# Processing Record 20 of Set 14 | fort morgan
# Processing Record 21 of Set 14 | nombre de dios
# Processing Record 22 of Set 14 | paamiut
# Processing Record 23 of Set 14 | clarence town
# Processing Record 24 of Set 14 | kruisfontein
# Processing Record 25 of Set 14 | mukhen
# Processing Record 26 of Set 14 | sola
# Processing Record 27 of Set 14 | khash
# Processing Record 28 of Set 14 | roma
# Processing Record 29 of Set 14 | la serena
# Processing Record 30 of Set 14 | howard springs
# Processing Record 31 of Set 14 | san francisco
# Processing Record 32 of Set 14 | kathmandu
# Processing Record 33 of Set 14 | kloulklubed
# Processing Record 34 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 14 | tambopata
# Processing Record 36 of Set 14 | miguel hidalgo
# Processing Record 37 of Set 14 | mount isa
# Processing Record 38 of Set 14 | turan
# Processing Record 39 of Set 14 | yarada
# Processing Record 40 of Set 14 | kosh-agach
# Processing Record 41 of Set 14 | kamloops
# Processing Record 42 of Set 14 | oyama
# Processing Record 43 of Set 14 | yoichi
# Processing Record 44 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 14 | sao joao da barra
# Processing Record 46 of Set 14 | davila
# Processing Record 47 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 48 of Set 14 | luderitz
# Processing Record 49 of Set 14 | vietri sul mare
# Processing Record 50 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 15 | zwedru
# Processing Record 2 of Set 15 | astoria
# Processing Record 3 of Set 15 | viedma
# Processing Record 4 of Set 15 | minab
# Processing Record 5 of Set 15 | lodja
# Processing Record 6 of Set 15 | tete
# Processing Record 7 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 8 of Set 15 | walla walla
# Processing Record 9 of Set 15 | ciudad bolivar
# Processing Record 10 of Set 15 | gornopravdinsk
# Processing Record 11 of Set 15 | makubetsu
# Processing Record 12 of Set 15 | buckeye
# Processing Record 13 of Set 15 | yarensk
# Processing Record 14 of Set 15 | moree
# Processing Record 15 of Set 15 | maridi
# Processing Record 16 of Set 15 | mokhsogollokh
# Processing Record 17 of Set 15 | iquitos
# Processing Record 18 of Set 15 | mujiayingzi
# Processing Record 19 of Set 15 | kadoma
# Processing Record 20 of Set 15 | comarapa
# Processing Record 21 of Set 15 | barinas
# Processing Record 22 of Set 15 | nelas
# Processing Record 23 of Set 15 | lewiston
# Processing Record 24 of Set 15 | werda
# Processing Record 25 of Set 15 | youkounkoun
# Processing Record 26 of Set 15 | kyrksaeterora
# Processing Record 27 of Set 15 | paita
# Processing Record 28 of Set 15 | mitu
# Processing Record 29 of Set 15 | lompoc
# Processing Record 30 of Set 15 | dunda
# Processing Record 31 of Set 15 | lumberton
# Processing Record 32 of Set 15 | dabwali
# Processing Record 33 of Set 15 | penzance
# Processing Record 34 of Set 15 | kenai
# Processing Record 35 of Set 15 | auray
# Processing Record 36 of Set 15 | leirvik
# Processing Record 37 of Set 15 | mayya
# Processing Record 38 of Set 15 | pacific grove
# Processing Record 39 of Set 15 | nishihara
# Processing Record 40 of Set 15 | gimli
# Processing Record 41 of Set 15 | san sebastian
# Processing Record 42 of Set 15 | eha amufu
# Processing Record 43 of Set 15 | innisfail
# Processing Record 44 of Set 15 | huilong
# Processing Record 45 of Set 15 | ilebo
# Processing Record 46 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 15 | surt
# Processing Record 48 of Set 15 | matagami
# Processing Record 49 of Set 15 | pemangkat
# Processing Record 50 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 16 | maneadero
# Processing Record 2 of Set 16 | kazerun
# Processing Record 3 of Set 16 | the pas
# Processing Record 4 of Set 16 | tari
# Processing Record 5 of Set 16 | jackson
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Esperance -33.8667  121.9000     47.93        77           1
# 1        Barrow  71.2906 -156.7887     33.82        80          75
# 2     Jamestown  42.0970  -79.2353     52.02        66         100
# 3       Mataura -46.1927  168.8643     33.01        98          11
# 4     Ostrovnoy  68.0531   39.5131     41.22        87          22
# 5       Yeppoon -23.1333  150.7333     64.18        80           9
# 6        Albany  42.6001  -73.9662     71.17        68          26
# 7  Rio Gallegos -51.6226  -69.2181     48.25        43          40
# 8        Avarua -21.2078 -159.7750     73.45        88          75
# 9  Nawalapitiya   7.0559   80.5348     68.92        90          98
#
#    Wind Speed Country                 Date Current Description
# 0        9.13      AU  2022-10-07 17:38:52           clear sky
# 1       19.57      US  2022-10-07 17:40:21       broken clouds
# 2       14.97      US  2022-10-07 17:38:25     overcast clouds
# 3        2.46      NZ  2022-10-07 17:40:22          few clouds
# 4       11.95      RU  2022-10-07 17:40:22          few clouds
# 5        8.84      AU  2022-10-07 17:40:23           clear sky
# 6       12.24      US  2022-10-07 17:35:26    scattered clouds
# 7       24.16      AR  2022-10-07 17:38:47    scattered clouds
# 8        4.61      CK  2022-10-07 17:40:23       broken clouds
# 9        1.74      LK  2022-10-07 17:40:24     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Esperance      AU -33.8667  121.9000     47.93        77           1
# 1       Barrow      US  71.2906 -156.7887     33.82        80          75
# 2    Jamestown      US  42.0970  -79.2353     52.02        66         100
# 3      Mataura      NZ -46.1927  168.8643     33.01        98          11
# 4    Ostrovnoy      RU  68.0531   39.5131     41.22        87          22
# ..         ...     ...      ...       ...       ...       ...         ...
# 686  Maneadero      MX  31.7167 -116.5667     69.10        86           4
# 687    Kazerun      IR  29.6195   51.6541     78.78        12           0
# 688    The Pas      CA  53.8251 -101.2541     48.63        42          97
# 689       Tari      NG  12.4086    4.4914     86.94        51          17
# 690    Jackson      US  42.4165 -122.8345     75.36        50          92
#
#      Wind Speed Current Description
# 0          9.13           clear sky
# 1         19.57       broken clouds
# 2         14.97     overcast clouds
# 3          2.46          few clouds
# 4         11.95          few clouds
# ..          ...                 ...
# 686        1.99           clear sky
# 687        5.79           clear sky
# 688       13.73     overcast clouds
# 689        6.49          few clouds
# 690        1.41     overcast clouds
#
# [691 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
